# %%
import numpy as np
import pandas as pd

# %%
match = pd.read_csv('..\Datasets\matches.csv')
delivery = pd.read_csv('..\Datasets\deliveries.csv')

# %%
#Unique values
#No of unique ipl teams so far

teams = delivery['batting_team']
teams.unique()
# Out:
# array(['Kolkata Knight Riders', 'Royal Challengers Bangalore',
#        'Chennai Super Kings', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Mumbai Indians', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
#no of teams
teams.nunique()
# Out:
# 19

# %%
#no of players
no_of_players  = delivery['batter']
no_of_players.nunique()
# Out:
# 673

# %%
#names of columns

match.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
delivery.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
#to get some samples

match.sample(5)
# Out:
#           id   season        city        date match_type player_of_match  \
# 830  1254072     2021      Mumbai  2021-04-21     League    F du Plessis
# 116   419107  2009/10      Mumbai  2010-03-13     League       YK Pathan
# 787  1216526  2020/21   Abu Dhabi  2020-10-16     League       Q de Kock
# 562   980991     2016  Chandigarh  2016-05-15     League         HM Amla
# 671  1136596     2018   Hyderabad  2018-05-05     League     Rashid Khan
#
#                                                  venue                  team1  \
# 830                           Wankhede Stadium, Mumbai    Chennai Super Kings
# 116                                  Brabourne Stadium         Mumbai Indians
# 787                               Sheikh Zayed Stadium  Kolkata Knight Riders
# 562  Punjab Cricket Association IS Bindra Stadium, ...        Kings XI Punjab
# 671                 Rajiv Gandhi International Stadium       Delhi Daredevils
#
# ...

# %%
delivery.sample(3)
# Out:
#         match_id  inning      batting_team                 bowling_team  over  \
# 90516     598056       2   Kings XI Punjab          Sunrisers Hyderabad     9
# 161028   1136605       1  Delhi Daredevils  Royal Challengers Bangalore    13
# 193400   1237181       1    Delhi Capitals               Mumbai Indians     3
#
#         ball     batter     bowler    non_striker  batsman_runs  extra_runs  \
# 90516      5  R Sathish  DJG Sammy  LA Pomersbach             1           0
# 161028     5  V Shankar  YS Chahal        SS Iyer             0           0
# 193400     1   S Dhawan    J Yadav        SS Iyer             1           0
#
#         total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# 90516            1         NaN          0              NaN            NaN
# 161028           0         NaN          0              NaN            NaN
# 193400           1         NaN          0              NaN            NaN
#
#        fielder
# 90516      NaN
# ...
