# %%
import numpy as np
import pandas as pd

# %%
match = pd.read_csv('..\Datasets\matches.csv')
delivery = pd.read_csv('..\Datasets\deliveries.csv')

# %%
#Unique values
#No of unique ipl teams so far

teams = delivery['batting_team']
teams.unique()
# Out:
# array(['Kolkata Knight Riders', 'Royal Challengers Bangalore',
#        'Chennai Super Kings', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Mumbai Indians', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
#no of teams
teams.nunique()
# Out:
# 19

# %%
#no of players
no_of_players  = delivery['batter']
no_of_players.nunique()
# Out:
# 673

# %%
#names of columns

match.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
delivery.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
#to get some samples

match.sample(5)
# Out:
#            id season       city        date match_type player_of_match  \
# 228    501252   2011     Jaipur  2011-05-11     League       S Aravind
# 1062  1426277   2024    Chennai  2024-04-23     League      MP Stoinis
# 458    829705   2015    Kolkata  2015-04-08     League        M Morkel
# 1023  1370353   2023  Ahmedabad  2023-05-29      Final       DP Conway
# 310    548370   2012     Mumbai  2012-05-16     League       SP Narine
#
#                                          venue                  team1  \
# 228                     Sawai Mansingh Stadium       Rajasthan Royals
# 1062  MA Chidambaram Stadium, Chepauk, Chennai    Chennai Super Kings
# 458                               Eden Gardens  Kolkata Knight Riders
# 1023          Narendra Modi Stadium, Ahmedabad         Gujarat Titans
# 310                           Wankhede Stadium         Mumbai Indians
#
#                             team2                  toss_winner toss_decision  \
# 228   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1062         Lucknow Super Giants         Lucknow Super Giants         field
# 458                Mumbai Indians        Kolkata Knight Riders         field
# 1023          Chennai Super Kings          Chennai Super Kings         field
# 310         Kolkata Knight Riders               Mumbai Indians         field
#
#                            winner   result  result_margin  target_runs  \
# 228   Royal Challengers Bangalore  wickets            9.0        147.0
# 1062         Lucknow Super Giants  wickets            6.0        211.0
# 458         Kolkata Knight Riders  wickets            7.0        169.0
# 1023          Chennai Super Kings  wickets            5.0        171.0
# 310         Kolkata Knight Riders     runs           32.0        141.0
#
#       target_overs super_over method          umpire1        umpire2
# 228           20.0          N    NaN  HDPK Dharmasena    K Hariharan
# 1062          20.0          N    NaN    NA Patwardhan   Tapan Sharma
# 458           20.0          N    NaN           S Ravi  C Shamshuddin
# 1023          15.0          N    D/L      Nitin Menon      RJ Tucker
# 310           20.0          N    NaN            S Das    BR Doctrove

# %%
delivery.sample(3)
# Out:
#         match_id  inning      batting_team     bowling_team  over  ball  \
# 189563   1216535       1    Delhi Capitals   Mumbai Indians    10     4
# 219486   1304094       1    Gujarat Titans     Punjab Kings     3     2
# 36242     419143       2  Rajasthan Royals  Kings XI Punjab     0     7
#
#          batter       bowler      non_striker  batsman_runs  extra_runs  \
# 189563  RR Pant    RD Chahar       MP Stoinis             1           0
# 219486  WP Saha     K Rabada  B Sai Sudharsan             0           4
# 36242   MJ Lumb  S Sreesanth          NV Ojha             0           0
#
#         total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# 189563           1         NaN          0              NaN            NaN
# 219486           4     legbyes          0              NaN            NaN
# 36242            0         NaN          0              NaN            NaN
#
#        fielder
# 189563     NaN
# 219486     NaN
# 36242      NaN
